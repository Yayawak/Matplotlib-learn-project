# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 100, 100)
# x = np.arange(0, 100)
l = len(x)
y = np.random.binomial(100, 0.9, l)
plt.plot(x, y)

# %% [markdown]
# ### Tossing Dice

# %%
import seaborn as sn
n, p = 20, 0.5

# sn.displot(np.random.binomial(n, p, size=1000), kde=True)
samp = np.random.binomial(n, p, 1000)
bin = np.arange(0, 20, 1)
plt.hist(samp, bins=bin, edgecolor='blue')
plt.title('Binomial Distribution')
plt.show()
