# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
n = 1000
df = pd.DataFrame(dict(time = np.arange(n),
                      value = np.random.randn(n).cumsum())
                 )
df
# Out:
#      time     value
# 0       0  1.510812
# 1       1  0.499912
# 2       2  0.480389
# 3       3 -0.120157
# 4       4 -1.252300
# ..    ...       ...
# 995   995 -5.907619
# 996   996 -4.237484
# 997   997 -2.531373
# 998   998 -3.890147
# 999   999 -3.574850
#
# [1000 rows x 2 columns]

# %%
np.random.randn(10).cumsum()
# Out:
# array([ 0.14087033, -0.93301731, -0.27750036, -0.27934661, -1.11521716,
#        -1.22144969, -1.29083704, -2.2646027 , -3.33524394, -2.65098841])

# %%
g = sns.relplot(x='time', y='value', data=df, kind='line')
g.fig.autofmt_xdate()
