# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
uri = '../Sample data/Cost_of_Living_Index_2022.csv'

# %%
# cols = ['Rank', 'Country', 'Cost of living', 'Rent idx', 
#         'Living + rent',
#        'Groceries', 'Restaurant price', 'Local buy power']
df = pd.read_csv(uri, skiprows=1, index_col='Rank',) # names=cols
df.sample(10)
# Out:
#                      Country  Cost of Living Index  Rent Index  \
# Rank
# 69                    Latvia                 48.45       11.77
# 115              South Korea                 73.22       20.02
# 63                    Jersey                 92.02       65.33
# 82                Montenegro                 38.95       12.87
# 30                      Cuba                 55.00       15.23
# 46                    Greece                 56.22       12.68
# 18    Bosnia And Herzegovina                 36.12        6.82
# 61                   Jamaica                 49.67       15.10
# 24                    Canada                 70.22       34.33
# 31                    Cyprus                 59.03       22.36
#
#       Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# Rank
# 69                             31.26            38.37                   42.10
# 115                            48.28            91.95                   42.10
# ...

# %%
# interest in "Cost of living" factor
df.dtypes
# Out:
# Country                            object
# Cost of Living Index              float64
# Rent Index                        float64
# Cost of Living Plus Rent Index    float64
# Groceries Index                   float64
# Restaurant Price Index            float64
# Local Purchasing Power Index      float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Country', 'Cost of Living Index', 'Rent Index',
#        'Cost of Living Plus Rent Index', 'Groceries Index',
#        'Restaurant Price Index', 'Local Purchasing Power Index'],
#       dtype='object')

# %%
df.info() # 6 var
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 1 to 139
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         139 non-null    object
#  1   Cost of Living Index            139 non-null    float64
#  2   Rent Index                      139 non-null    float64
#  3   Cost of Living Plus Rent Index  139 non-null    float64
#  4   Groceries Index                 139 non-null    float64
#  5   Restaurant Price Index          139 non-null    float64
#  6   Local Purchasing Power Index    139 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.7+ KB

# %%
df.isnull().sum()
# Out:
# Country                           0
# Cost of Living Index              0
# Rent Index                        0
# Cost of Living Plus Rent Index    0
# Groceries Index                   0
# Restaurant Price Index            0
# Local Purchasing Power Index      0
# dtype: int64

# %%
sns.set_style('whitegrid')
df2 = df.sample(10, replace=True)
plt.rcParams.update({'font.size':14})
plt.xticks(rotation=50)
sns.barplot(x=df2['Country'], y=df2['Cost of Living Index'], color='r')
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Cost of Living Index'>

# %%
# df

# %% [raw]
# Local Purchasing Power Index
# Cost of Living Index

# %%
sns.scatterplot(x=df['Local Purchasing Power Index'], 
                y=df['Cost of Living Index'])
# Out:
# <AxesSubplot:xlabel='Local Purchasing Power Index', ylabel='Cost of Living Index'>

# %%
df.columns[0]
# Out:
# 'Country'

# %%
df[df.columns[0]]
# Out:
# Rank
# 1      Afghanistan
# 2          Albania
# 3          Algeria
# 4        Argentina
# 5          Armenia
#           ...
# 135      Venezuela
# 136        Vietnam
# 137          Yemen
# 138         Zambia
# 139       Zimbabwe
# Name: Country, Length: 139, dtype: object

# %%
sns.scatterplot(x=df[df.columns[1]],
               y=df[df.columns[-1]])
# Out:
# <AxesSubplot:xlabel='Cost of Living Index', ylabel='Local Purchasing Power Index'>

# %%
sns.scatterplot(x=df[df.columns[-1]], 
               y=df[df.columns[1]])
sns.scatterplot(x=df[df.columns[-2]], 
               y=df[df.columns[1]])
sns.scatterplot(x=df[df.columns[-3]], 
               y=df[df.columns[1]])
# Out:
# <AxesSubplot:xlabel='Local Purchasing Power Index', ylabel='Cost of Living Index'>

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 3))
sns.scatterplot(x=df[df.columns[-1]], 
               y=df[df.columns[1]],
               ax=axes[0])
sns.scatterplot(x=df[df.columns[-2]], 
               y=df[df.columns[1]],
               ax=axes[1])
sns.scatterplot(x=df[df.columns[-3]], 
               y=df[df.columns[1]],
               ax=axes[2])
# Out:
# <AxesSubplot:xlabel='Groceries Index', ylabel='Cost of Living Index'>

# %%
sns.scatterplot(x=df[df.columns[1]])
