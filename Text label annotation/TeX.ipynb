# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(8,6))
ax.plot([1, 2, 3], label=r'$\sqrt{x^2}$')
ax.legend()

ax.set_ylabel(r'$\Delta_{1+i}^j$', fontsize=20)
ax.set_xlabel(r'$\Delta_i^j$', fontsize=20)

tex = r'$\mathcal{R} = \prod_{i=\alpha_{i+1}}^\infty$ ' \
        r'$\alpha_isin(2 \pi f x_i)$'
ax.text(1.5, 2, tex, fontsize=25, va='bottom')

# fig.tight_layout()
plt.show()
