# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.plot(range(10), '--')
ax.set_title(r'$\hat{A}\vec{V}\bar{B}$', fontsize=20)

ax.text(5, .5, r'$\vec{F} = m\vec{a}$', fontsize='xx-large', rotation=45)
fig.tight_layout()
